# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import torch
import sentencepiece as spm

from decode_korean_cer import get_parser
from train import get_transducer_model
from keyword_spotting import get_model
from asr_datamodule import AsrDataModule
device = "cpu"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       6 from decode_korean_cer import get_parser
#       7 from train import get_transducer_model
# ----> 8 from keyword_spotting import get_model
#       9 from asr_datamodule import AsrDataModule
#      10 device = "cpu"
#
# File ~/Documents/icefall/egs/librispeech/ASR/ema/keyword_spotting.py:25
#      23 from update_bn import update_bn
#      24 from beam_search import fast_beam_search_one_best
# ---> 25 from local.custom_fbank import CustomFbank, CustomFbankConfig
#      27 from icefall.checkpoint import (
#      28     average_checkpoints,
#      29     average_checkpoints_with_averaged_model,
#      30     find_checkpoints,
#      31     load_checkpoint,
#      32 )
#      33 from icefall.lexicon import Lexicon
#
# ModuleNotFoundError: No module named 'local'

# %%
parser = get_parser()
args = parser.parse_args()
args.exp_dir = Path(args.exp_dir)
params = get_params()
params.update(vars(args))
params.vocab_size = sp.get_piece_size()

sp = spm.SentencePieceProcessor()
sp.load(params.bpe_model)
AsrDataModule.add_arguments(parser)

model = get_transducer_model(params)
get_model(params, model, device, args, sp, args.exp_dir / f"epoch-{args.epoch}-avg-{args.avg}.pt")
