# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import torch

x = torch.randn(1024) * 10
x = torch.sort(x)[0]
from fp8 import q_fp8
plt.plot(x)
# plt.hist(x.numpy(), bins=100)
q_fp8(x, "test_tensor")
plt.plot(x)
# plt.hist(x.numpy(), bins=100)
plt.show()
# Out:
# test_tensor: 5
